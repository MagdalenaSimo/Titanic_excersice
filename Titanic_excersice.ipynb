# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
titanic_survived = pd.read_csv('gender_submission.csv')
titanic_survived
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
titanic_passenger = pd.read_csv('test.csv')
titanic_passenger
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#merged two tables together
titanic_train = pd.merge(titanic_passenger,titanic_survived,how='inner',on='PassengerId')
titanic_train
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#removed the tickets and cabin atribute

titanic_train.drop(columns=['Ticket','Cabin'])
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#find the null values in dataframe
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
# Replace using median in column Age
median = titanic_train['Age'].median()
titanic_train['Age'].fillna(median, inplace=True)
titanic_train
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#replace the null values in column Fare
median2 = titanic_train['Fare'].median()
titanic_train['Fare'].fillna(median2, inplace=True)
titanic_train
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#how many null values is in the dataframe
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
#remove the null values in cabin 
titanic_train.dropna(inplace=True)
titanic_train
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# 34           926       1                           Mock, Mr. Philipp Edmund
# 41           933       1                        Franklin, Mr. Thomas Parham
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 50           942       1                           Smith, Mr. Lucien Philip
# ...

# %%
#find the null values in dataframe
titanic_train.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Survived       0
# dtype: int64

# %%
#find the values Survived
x =titanic_train['Survived'].value_counts() *100/len(titanic_train)
x
# Out:
# 0    51.648352
# 1    48.351648
# Name: Survived, dtype: float64

# %%
#show survived in grapf
alpha_color=0.5
titanic_train['Survived'].value_counts().plot(kind='bar')

# %%
#how many sex was in the titanic
titanic_train['Sex'].value_counts()
# Out:
# male      47
# female    44
# Name: Sex, dtype: int64

# %%
#show the sex value in grapf
titanic_train['Sex'].value_counts().plot(kind='bar')

# %%
#how many people lived in Pclass in titanic
titanic_train['Pclass'].value_counts()
# Out:
# 1    80
# 2     7
# 3     4
# Name: Pclass, dtype: int64

# %%
#how many people with sex male survived
titanic_train[titanic_train['Sex'] == 'male']['Survived'].value_counts().plot(kind='bar')

# %%
#how many people with sex female survived
titanic_train[titanic_train['Sex'] == 'female']['Survived'].value_counts().plot(kind='bar')

# %%
#how many people with sex male living in pclass 1 survived
titanic_train[(titanic_train['Sex'] == 'male') & (titanic_train['Pclass'] == 1)] ['Survived'].value_counts().plot(kind='bar')

# %%
#how many people with sex male living in pclass 2 survived
titanic_train[(titanic_train['Sex'] == 'female') & (titanic_train['Pclass'] == 2)] ['Survived'].value_counts().plot(kind='bar')

# %%
#how many people with sex male living in pclass 3 survived

titanic_train[(titanic_train['Sex'] == 'female') & (titanic_train['Pclass'] == 3)] ['Survived'].value_counts().plot(kind='bar')

# %%
titanic_train['SibSp'].value_counts().sort_index().plot(kind='bar')
